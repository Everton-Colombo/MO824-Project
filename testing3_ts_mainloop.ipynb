# %%
from agricultural_csp.instance import *
from agricultural_csp.evaluator import *
from agricultural_csp.solver.agcsp_ts import *

import numpy as np
import matplotlib.pyplot as plt
from typing import List, Tuple

# %%
def display_grid_and_path(inst, evaluator, path):
    """
    Display a grid with nodes and path coverage visualization.
    
    Args:
        inst: AgcspInstance object containing grid_nodes and obstacle_nodes
        evaluator: AgcspEvaluator object to calculate coverage
        path: List of (row, col) tuples representing the path
    """
    covered_nodes = evaluator.get_covered_nodes_list(path)
    
    total_nodes = len(inst.field_nodes)
    covered_count = len(covered_nodes)
    coverage_percentage = (covered_count / total_nodes) * 100 if total_nodes > 0 else 0
    
    # Check for obstacle coverage
    covered_obstacles = []
    obstacle_warning = ""
    if hasattr(inst, 'obstacle_nodes') and len(inst.obstacle_nodes) > 0:
        covered_set = set(map(tuple, covered_nodes))
        covered_obstacles = [obs for obs in inst.obstacle_nodes if tuple(obs) in covered_set]
        if covered_obstacles:
            obstacle_warning = f" - {len(covered_obstacles)} obstacles covered!"
    
    plt.figure(figsize=(12, 10))
    
    # Plot valid nodes
    plt.scatter(inst.grid_nodes[:, 0], inst.grid_nodes[:, 1], c='#AAAAAA', s=3, 
               label='Uncovered Nodes', alpha=0.7)
    
    if len(covered_nodes) > 0:
        plt.scatter(covered_nodes[:, 0], covered_nodes[:, 1], c='#00AA44', s=4, 
                   label='Covered Nodes', alpha=0.8)
    
    # Plot obstacles
    if hasattr(inst, 'obstacle_nodes') and len(inst.obstacle_nodes) > 0:
        plt.scatter(inst.obstacle_nodes[:, 0], inst.obstacle_nodes[:, 1], c='#CC0000', s=4, 
                   marker='s', label='Obstacles', linewidths=0.5)
        
        # Highlight covered obstacles
        if covered_obstacles:
            covered_obstacles_arr = np.array(covered_obstacles)
            plt.scatter(covered_obstacles_arr[:, 0], covered_obstacles_arr[:, 1], 
                       c='#FF6600', s=10, marker='D', 
                       linewidths=2, label='Covered Obstacles')
    
    # Plot path
    if len(path) > 0:
        path_arr = np.array(path)
        plt.plot(path_arr[:, 0], path_arr[:, 1], color='#9900CC', linewidth=3, 
                label='Sprayer Path', marker='o', markersize=6, markerfacecolor='white', 
                markeredgecolor='#9900CC', markeredgewidth=2)
    
    # Plot start point (green star)
    if len(path) > 0:
        plt.scatter(path_arr[0, 0], path_arr[0, 1], c='#00DD00', s=200, 
                   marker='*', label='Start', edgecolors='black', linewidths=2, zorder=5)
    
    # Plot end point (red square)
    if len(path) > 1:
        plt.scatter(path_arr[-1, 0], path_arr[-1, 1], c='#DD0000', s=100, 
                   marker='s', label='End', edgecolors='black', linewidths=2, zorder=5)
    
    plt.axis('equal')
    plt.legend(loc='upper right', framealpha=0.9)
    
    title = f'Coverage: {covered_count}/{total_nodes} nodes ({coverage_percentage:.1f}%){obstacle_warning}'
    plt.title(title, fontsize=12, fontweight='bold')
    
    print(f"Coverage: {covered_count}/{total_nodes} nodes ({coverage_percentage:.1f}%)")
    if hasattr(inst, 'obstacle_nodes') and len(inst.obstacle_nodes) > 0:
        print(f"Obstacles: {len(covered_obstacles)}/{len(inst.obstacle_nodes)} covered")
        if covered_obstacles:
            print("WARNING: Sprayer is covering obstacles!")
    
    plt.show()

# %%
# Create a 50 x 50 square grid with five small square obstacles scattered on the grid
obstacle_half_size = 2  # Half-size of each small square obstacle

r_grid, c_grid = np.mgrid[0:50, 0:50]
grid_nodes = np.argwhere((r_grid >= 0) & (r_grid < 50) & (c_grid >= 0) & (c_grid < 50))

# Create five small square obstacles at different positions on the grid
obstacle_positions = [
    (10, 10),  # Top-left area
    (10, 40),  # Top-right area
    (25, 25),  # Center
    (40, 10),  # Bottom-left area
    (40, 40)   # Bottom-right area
]

obstacle_list = []
for obs_r, obs_c in obstacle_positions:
    obstacle = np.argwhere(
        (np.abs(r_grid - obs_r) <= obstacle_half_size) & 
        (np.abs(c_grid - obs_c) <= obstacle_half_size)
    )
    obstacle_list.append(obstacle)

# obstacle_nodes = np.vstack(obstacle_list)

instance = AgcspInstance(grid_nodes, np.array([]), 5, 90)
evaluator = AgcspEvaluator(instance)

# %%
display_grid_and_path(inst=instance, evaluator=evaluator, path=[])
# Out:
# Coverage: 0/2500 nodes (0.0%)

# %%
strategy = TSStrategy(
    constructive_heuristic=ConstructiveHeuristicType.RANDOM,
    phased_optimization=PhasedOptimizationParams(phase_iterations=[10, 10, 10],)
)
term_criteria = TerminationCriteria(max_iterations=100)
debug_options = DebugOptions(verbose=True)

ts = AgcspTS(instance, tenure=100,strategy=strategy, termination_criteria=term_criteria, debug_options=debug_options)

# %%
solution = ts.solve()
# Out:
# Current coverage: 0.0020, path length: 1, uncovered: 2495
# Current coverage: 0.0372, path length: 2, uncovered: 2407
# Current coverage: 0.0796, path length: 3, uncovered: 2301
# Current coverage: 0.1112, path length: 4, uncovered: 2222
# Current coverage: 0.1628, path length: 5, uncovered: 2093
# Current coverage: 0.1876, path length: 6, uncovered: 2031
# Current coverage: 0.2348, path length: 7, uncovered: 1913
# Current coverage: 0.2444, path length: 8, uncovered: 1889
# Current coverage: 0.2728, path length: 9, uncovered: 1818
# Current coverage: 0.2800, path length: 10, uncovered: 1800
# Current coverage: 0.2824, path length: 11, uncovered: 1794
# Current coverage: 0.3356, path length: 12, uncovered: 1661
# Current coverage: 0.4004, path length: 13, uncovered: 1499
# Current coverage: 0.4288, path length: 14, uncovered: 1428
# Current coverage: 0.4672, path length: 15, uncovered: 1332
# Current coverage: 0.4940, path length: 16, uncovered: 1265
# Current coverage: 0.5352, path length: 17, uncovered: 1162
# Current coverage: 0.5476, path length: 18, uncovered: 1131
# Current coverage: 0.5792, path length: 19, uncovered: 1052
# Current coverage: 0.6084, path length: 20, uncovered: 979
# Current coverage: 0.6336, path length: 21, uncovered: 916
# Current coverage: 0.6488, path length: 22, uncovered: 878
# Current coverage: 0.6572, path length: 23, uncovered: 857
# Current coverage: 0.7000, path length: 24, uncovered: 750
# Current coverage: 0.7100, path length: 25, uncovered: 725
# Current coverage: 0.7300, path length: 26, uncovered: 675
# Current coverage: 0.7408, path length: 27, uncovered: 648
# Current coverage: 0.7648, path length: 28, uncovered: 588
# Current coverage: 0.7740, path length: 29, uncovered: 565
# Current coverage: 0.7828, path length: 30, uncovered: 543
# Current coverage: 0.8028, path length: 31, uncovered: 493
# Current coverage: 0.8064, path length: 32, uncovered: 484
# Current coverage: 0.8092, path length: 33, uncovered: 477
# Current coverage: 0.8120, path length: 34, uncovered: 470
# Current coverage: 0.8356, path length: 35, uncovered: 411
# Current coverage: 0.8416, path length: 36, uncovered: 396
# Current coverage: 0.8520, path length: 37, uncovered: 370
# Current coverage: 0.8604, path length: 38, uncovered: 349
# Current coverage: 0.8672, path length: 39, uncovered: 332
# Current coverage: 0.8684, path length: 40, uncovered: 329
# Current coverage: 0.8716, path length: 41, uncovered: 321
# Current coverage: 0.8756, path length: 42, uncovered: 311
# Current coverage: 0.8804, path length: 43, uncovered: 299
# Current coverage: 0.8856, path length: 44, uncovered: 286
# Current coverage: 0.9008, path length: 45, uncovered: 248
# Current coverage: 0.9076, path length: 46, uncovered: 231
# Current coverage: 0.9128, path length: 47, uncovered: 218
# Current coverage: 0.9252, path length: 48, uncovered: 187
# Current coverage: 0.9276, path length: 49, uncovered: 181
# Current coverage: 0.9412, path length: 50, uncovered: 147
# Current coverage: 0.9476, path length: 51, uncovered: 131
# Current coverage: 0.9540, path length: 52, uncovered: 115
# Current coverage: 0.9544, path length: 53, uncovered: 114
# Current coverage: 0.9580, path length: 54, uncovered: 105
# Current coverage: 0.9616, path length: 55, uncovered: 96
# Current coverage: 0.9656, path length: 56, uncovered: 86
# Current coverage: 0.9676, path length: 57, uncovered: 81
# Current coverage: 0.9720, path length: 58, uncovered: 70
# Current coverage: 0.9748, path length: 59, uncovered: 63
# Current coverage: 0.9756, path length: 60, uncovered: 61
# Current coverage: 0.9792, path length: 61, uncovered: 52
# Iteration 0: Best ObjFun = 1221.11, Current ObjFun = 1221.11
# Iteration 1: Best ObjFun = 1205.08, Current ObjFun = 1205.08
# Iteration 2: Best ObjFun = 1205.08, Current ObjFun = 1235.55
# Iteration 3: Best ObjFun = 1205.08, Current ObjFun = 1231.27
# Iteration 4: Best ObjFun = 1205.08, Current ObjFun = 1228.74
# Iteration 5: Best ObjFun = 1205.08, Current ObjFun = 1232.53
# Iteration 6: Best ObjFun = 1205.08, Current ObjFun = 1236.25
# Iteration 7: Best ObjFun = 1205.08, Current ObjFun = 1225.35
# Iteration 8: Best ObjFun = 1205.08, Current ObjFun = 1229.21
# Iteration 9: Best ObjFun = 1205.08, Current ObjFun = 1230.82
#
# === Switching to Phase 2 ===
# Current best components: Cov=34.00, Dist=1136.23, Man=34.85
# Iteration 10: Best ObjFun = 1205.08, Current ObjFun = 1236.51
# Iteration 11: Best ObjFun = 1205.08, Current ObjFun = 1235.99
# Iteration 12: Best ObjFun = 1205.08, Current ObjFun = 1236.00
# Iteration 13: Best ObjFun = 1205.08, Current ObjFun = 1236.00
# Iteration 14: Best ObjFun = 1205.08, Current ObjFun = 1232.73
# Iteration 15: Best ObjFun = 1205.08, Current ObjFun = 1231.65
# Iteration 16: Best ObjFun = 1205.08, Current ObjFun = 1231.65
# Iteration 17: Best ObjFun = 1205.08, Current ObjFun = 1231.65
# Iteration 18: Best ObjFun = 1205.08, Current ObjFun = 1231.65
# Iteration 19: Best ObjFun = 1205.08, Current ObjFun = 1231.65
#
# === Switching to Phase 3 ===
# Current best components: Cov=34.00, Dist=1136.23, Man=34.85
# Iteration 20: Best ObjFun = 1205.08, Current ObjFun = 1231.65
# Iteration 21: Best ObjFun = 1205.08, Current ObjFun = 1231.64
# Iteration 22: Best ObjFun = 1205.08, Current ObjFun = 1227.46
# Iteration 23: Best ObjFun = 1205.08, Current ObjFun = 1228.14
# Iteration 24: Best ObjFun = 1205.08, Current ObjFun = 1228.13
# Iteration 25: Best ObjFun = 1205.08, Current ObjFun = 1228.12
# Iteration 26: Best ObjFun = 1205.08, Current ObjFun = 1228.24
# Iteration 27: Best ObjFun = 1205.08, Current ObjFun = 1227.27
# Iteration 28: Best ObjFun = 1205.08, Current ObjFun = 1230.45
# Iteration 29: Best ObjFun = 1205.08, Current ObjFun = 1233.81
#
# === Switching to Phase 1 ===
# Current best components: Cov=34.00, Dist=1136.23, Man=34.85
# Iteration 30: Best ObjFun = 1205.08, Current ObjFun = 1234.82
# Iteration 31: Best ObjFun = 1205.08, Current ObjFun = 1238.18
# Iteration 32: Best ObjFun = 1205.08, Current ObjFun = 1229.79
# Iteration 33: Best ObjFun = 1205.08, Current ObjFun = 1228.27
# Iteration 34: Best ObjFun = 1205.08, Current ObjFun = 1227.48
# Iteration 35: Best ObjFun = 1205.08, Current ObjFun = 1229.18
# Iteration 36: Best ObjFun = 1205.08, Current ObjFun = 1229.18
# Iteration 37: Best ObjFun = 1205.08, Current ObjFun = 1229.18
# Iteration 38: Best ObjFun = 1205.08, Current ObjFun = 1229.18
# Iteration 39: Best ObjFun = 1205.08, Current ObjFun = 1229.18
#
# === Switching to Phase 2 ===
# Current best components: Cov=34.00, Dist=1136.23, Man=34.85
# Iteration 40: Best ObjFun = 1205.08, Current ObjFun = 1229.18
# Iteration 41: Best ObjFun = 1205.08, Current ObjFun = 1230.10
# Iteration 42: Best ObjFun = 1205.08, Current ObjFun = 1230.10
# Iteration 43: Best ObjFun = 1205.08, Current ObjFun = 1230.10
# Iteration 44: Best ObjFun = 1205.08, Current ObjFun = 1230.10
# Iteration 45: Best ObjFun = 1205.08, Current ObjFun = 1230.10
# Iteration 46: Best ObjFun = 1205.08, Current ObjFun = 1230.10
# Iteration 47: Best ObjFun = 1205.08, Current ObjFun = 1230.10
# Iteration 48: Best ObjFun = 1205.08, Current ObjFun = 1230.10
# Iteration 49: Best ObjFun = 1205.08, Current ObjFun = 1230.10
#
# === Switching to Phase 3 ===
# Current best components: Cov=34.00, Dist=1136.23, Man=34.85
# Iteration 50: Best ObjFun = 1205.08, Current ObjFun = 1230.10
# Iteration 51: Best ObjFun = 1205.08, Current ObjFun = 1232.16
# Iteration 52: Best ObjFun = 1205.08, Current ObjFun = 1232.15
# Iteration 53: Best ObjFun = 1205.08, Current ObjFun = 1231.91
# Iteration 54: Best ObjFun = 1205.08, Current ObjFun = 1231.87
# Iteration 55: Best ObjFun = 1205.08, Current ObjFun = 1234.07
# Iteration 56: Best ObjFun = 1205.08, Current ObjFun = 1234.65
# Iteration 57: Best ObjFun = 1205.08, Current ObjFun = 1234.61
# Iteration 58: Best ObjFun = 1205.08, Current ObjFun = 1236.01
# Iteration 59: Best ObjFun = 1205.08, Current ObjFun = 1235.97
#
# === Switching to Phase 1 ===
# Current best components: Cov=34.00, Dist=1136.23, Man=34.85
# Iteration 60: Best ObjFun = 1205.08, Current ObjFun = 1235.92
# Iteration 61: Best ObjFun = 1205.08, Current ObjFun = 1234.07
# Iteration 62: Best ObjFun = 1205.08, Current ObjFun = 1232.88
# Iteration 63: Best ObjFun = 1205.08, Current ObjFun = 1234.33
# Iteration 64: Best ObjFun = 1205.08, Current ObjFun = 1233.46
# Iteration 65: Best ObjFun = 1205.08, Current ObjFun = 1233.46
# Iteration 66: Best ObjFun = 1205.08, Current ObjFun = 1233.46
# Iteration 67: Best ObjFun = 1205.08, Current ObjFun = 1233.46
# Iteration 68: Best ObjFun = 1205.08, Current ObjFun = 1233.46
# Iteration 69: Best ObjFun = 1205.08, Current ObjFun = 1233.46
#
# === Switching to Phase 2 ===
# Current best components: Cov=34.00, Dist=1136.23, Man=34.85
# Iteration 70: Best ObjFun = 1205.08, Current ObjFun = 1233.46
# Iteration 71: Best ObjFun = 1205.08, Current ObjFun = 1233.46
# Iteration 72: Best ObjFun = 1205.08, Current ObjFun = 1233.46
# Iteration 73: Best ObjFun = 1205.08, Current ObjFun = 1233.39
# Iteration 74: Best ObjFun = 1205.08, Current ObjFun = 1228.68
# Iteration 75: Best ObjFun = 1205.08, Current ObjFun = 1226.73
# Iteration 76: Best ObjFun = 1205.08, Current ObjFun = 1225.89
# Iteration 77: Best ObjFun = 1205.08, Current ObjFun = 1224.12
# Iteration 78: Best ObjFun = 1205.08, Current ObjFun = 1224.12
# Iteration 79: Best ObjFun = 1205.08, Current ObjFun = 1224.12
#
# === Switching to Phase 3 ===
# Current best components: Cov=34.00, Dist=1136.23, Man=34.85
# Iteration 80: Best ObjFun = 1205.08, Current ObjFun = 1224.12
# Iteration 81: Best ObjFun = 1204.92, Current ObjFun = 1204.92
# Iteration 82: Best ObjFun = 1204.81, Current ObjFun = 1204.81
# Iteration 83: Best ObjFun = 1204.81, Current ObjFun = 1206.40
# Iteration 84: Best ObjFun = 1204.81, Current ObjFun = 1205.00
# Iteration 85: Best ObjFun = 1204.81, Current ObjFun = 1209.01
# Iteration 86: Best ObjFun = 1204.81, Current ObjFun = 1208.99
# Iteration 87: Best ObjFun = 1204.81, Current ObjFun = 1209.14
# Iteration 88: Best ObjFun = 1204.81, Current ObjFun = 1209.12
# Iteration 89: Best ObjFun = 1204.81, Current ObjFun = 1210.15
#
# === Switching to Phase 1 ===
# Current best components: Cov=5.00, Dist=1163.30, Man=36.51
# Iteration 90: Best ObjFun = 1204.81, Current ObjFun = 1211.13
# Iteration 91: Best ObjFun = 1204.81, Current ObjFun = 1213.90
# Iteration 92: Best ObjFun = 1204.81, Current ObjFun = 1212.80
# Iteration 93: Best ObjFun = 1204.81, Current ObjFun = 1249.76
# Iteration 94: Best ObjFun = 1204.81, Current ObjFun = 1256.00
# Iteration 95: Best ObjFun = 1204.81, Current ObjFun = 1255.01
# Iteration 96: Best ObjFun = 1204.81, Current ObjFun = 1258.89
# Iteration 97: Best ObjFun = 1204.81, Current ObjFun = 1257.48
# Iteration 98: Best ObjFun = 1204.81, Current ObjFun = 1261.91
# Iteration 99: Best ObjFun = 1204.81, Current ObjFun = 1261.91

# %%
display_grid_and_path(instance, evaluator, solution.path)
# Out:
# Coverage: 2495/2500 nodes (99.8%)

# %%
solution.cache["hits_obstacle"]
# Out:
# False
