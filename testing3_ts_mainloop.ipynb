# %%
from agricultural_csp.instance import *
from agricultural_csp.evaluator import *
from agricultural_csp.solver.agcsp_ts import *

import numpy as np
import matplotlib.pyplot as plt
from typing import List, Tuple

# %%
def display_grid_and_path(inst, evaluator, path):
    """
    Display a grid with nodes and path coverage visualization.
    
    Args:
        inst: AgcspInstance object containing grid_nodes and obstacle_nodes
        evaluator: AgcspEvaluator object to calculate coverage
        path: List of (row, col) tuples representing the path
    """
    covered_nodes = evaluator.get_covered_nodes_list(path)
    
    total_nodes = len(inst.field_nodes)
    covered_count = len(covered_nodes)
    coverage_percentage = (covered_count / total_nodes) * 100 if total_nodes > 0 else 0
    
    # Check for obstacle coverage
    covered_obstacles = []
    obstacle_warning = ""
    if hasattr(inst, 'obstacle_nodes') and len(inst.obstacle_nodes) > 0:
        covered_set = set(map(tuple, covered_nodes))
        covered_obstacles = [obs for obs in inst.obstacle_nodes if tuple(obs) in covered_set]
        if covered_obstacles:
            obstacle_warning = f" - {len(covered_obstacles)} obstacles covered!"
    
    plt.figure(figsize=(12, 10))
    
    # Plot valid nodes
    plt.scatter(inst.grid_nodes[:, 0], inst.grid_nodes[:, 1], c='#AAAAAA', s=3, 
               label='Uncovered Nodes', alpha=0.7)
    
    if len(covered_nodes) > 0:
        plt.scatter(covered_nodes[:, 0], covered_nodes[:, 1], c='#00AA44', s=4, 
                   label='Covered Nodes', alpha=0.8)
    
    # Plot obstacles
    if hasattr(inst, 'obstacle_nodes') and len(inst.obstacle_nodes) > 0:
        plt.scatter(inst.obstacle_nodes[:, 0], inst.obstacle_nodes[:, 1], c='#CC0000', s=4, 
                   marker='s', label='Obstacles', linewidths=0.5)
        
        # Highlight covered obstacles
        if covered_obstacles:
            covered_obstacles_arr = np.array(covered_obstacles)
            plt.scatter(covered_obstacles_arr[:, 0], covered_obstacles_arr[:, 1], 
                       c='#FF6600', s=10, marker='D', 
                       linewidths=2, label='Covered Obstacles')
    
    # Plot path
    if len(path) > 0:
        path_arr = np.array(path)
        plt.plot(path_arr[:, 0], path_arr[:, 1], color='#9900CC', linewidth=3, 
                label='Sprayer Path', marker='o', markersize=6, markerfacecolor='white', 
                markeredgecolor='#9900CC', markeredgewidth=2)
    
    # Plot start point (green star)
    if len(path) > 0:
        plt.scatter(path_arr[0, 0], path_arr[0, 1], c='#00DD00', s=200, 
                   marker='*', label='Start', edgecolors='black', linewidths=2, zorder=5)
    
    # Plot end point (red square)
    if len(path) > 1:
        plt.scatter(path_arr[-1, 0], path_arr[-1, 1], c='#DD0000', s=100, 
                   marker='s', label='End', edgecolors='black', linewidths=2, zorder=5)
    
    plt.axis('equal')
    plt.legend(loc='upper right', framealpha=0.9)
    
    title = f'Coverage: {covered_count}/{total_nodes} nodes ({coverage_percentage:.1f}%){obstacle_warning}'
    plt.title(title, fontsize=12, fontweight='bold')
    
    print(f"Coverage: {covered_count}/{total_nodes} nodes ({coverage_percentage:.1f}%)")
    if hasattr(inst, 'obstacle_nodes') and len(inst.obstacle_nodes) > 0:
        print(f"Obstacles: {len(covered_obstacles)}/{len(inst.obstacle_nodes)} covered")
        if covered_obstacles:
            print("WARNING: Sprayer is covering obstacles!")
    
    plt.show()

# %%
# Create a 50 x 50 square grid with five small square obstacles scattered on the grid
obstacle_half_size = 2  # Half-size of each small square obstacle

r_grid, c_grid = np.mgrid[0:50, 0:50]
grid_nodes = np.argwhere((r_grid >= 0) & (r_grid < 50) & (c_grid >= 0) & (c_grid < 50))

# Create five small square obstacles at different positions on the grid
obstacle_positions = [
    (10, 10),  # Top-left area
    (10, 40),  # Top-right area
    (25, 25),  # Center
    (40, 10),  # Bottom-left area
    (40, 40)   # Bottom-right area
]

obstacle_list = []
for obs_r, obs_c in obstacle_positions:
    obstacle = np.argwhere(
        (np.abs(r_grid - obs_r) <= obstacle_half_size) & 
        (np.abs(c_grid - obs_c) <= obstacle_half_size)
    )
    obstacle_list.append(obstacle)

# obstacle_nodes = np.vstack(obstacle_list)

instance = AgcspInstance(grid_nodes, np.array([]), 5, 90)
evaluator = AgcspEvaluator(instance)

# %%
display_grid_and_path(inst=instance, evaluator=evaluator, path=[])
# Out:
# Coverage: 0/2500 nodes (0.0%)

# %%
ts = AgcspTS(instance, tenure=100,strategy=TSStrategy(constructive_heuristic=ConstructiveHeuristicType.RANDOM), termination_criteria=TerminationCriteria(max_iterations=10
                                                                                                                                                         ), debug_options=DebugOptions(verbose=True))

# %%
gen_path = ts._constructive_heuristic(ConstructiveHeuristicType.FSM_COVERAGE_PLANNER)
# Out:
# After axis scanning 'C', current coverage: 96.00%
# After axis scanning 'R', current coverage: 99.84%
# Path simplification reduced points from 1116 to 40.

# %%
evaluator.objfun(gen_path)
# Out:
# 2226.719480579337

# %%
display_grid_and_path(instance, evaluator, gen_path.path)
# Out:
# Coverage: 2496/2500 nodes (99.8%)

# %%
solution = ts.solve()
# Out:
# Current coverage: 0.0020, path length: 1, uncovered: 2495
# Current coverage: 0.0540, path length: 2, uncovered: 2365
# Current coverage: 0.0920, path length: 3, uncovered: 2270
# Current coverage: 0.1228, path length: 4, uncovered: 2193
# Current coverage: 0.1324, path length: 5, uncovered: 2169
# Current coverage: 0.1992, path length: 6, uncovered: 2002
# Current coverage: 0.2156, path length: 7, uncovered: 1961
# Current coverage: 0.2932, path length: 8, uncovered: 1767
# Current coverage: 0.3396, path length: 9, uncovered: 1651
# Current coverage: 0.3444, path length: 10, uncovered: 1639
# Current coverage: 0.3888, path length: 11, uncovered: 1528
# Current coverage: 0.4012, path length: 12, uncovered: 1497
# Current coverage: 0.4356, path length: 13, uncovered: 1411
# Current coverage: 0.4836, path length: 14, uncovered: 1291
# Current coverage: 0.4960, path length: 15, uncovered: 1260
# Current coverage: 0.5228, path length: 16, uncovered: 1193
# Current coverage: 0.5456, path length: 17, uncovered: 1136
# Current coverage: 0.5924, path length: 18, uncovered: 1019
# Current coverage: 0.6088, path length: 19, uncovered: 978
# Current coverage: 0.6644, path length: 20, uncovered: 839
# Current coverage: 0.6804, path length: 21, uncovered: 799
# Current coverage: 0.7056, path length: 22, uncovered: 736
# Current coverage: 0.7120, path length: 23, uncovered: 720
# Current coverage: 0.7208, path length: 24, uncovered: 698
# Current coverage: 0.7260, path length: 25, uncovered: 685
# Current coverage: 0.7380, path length: 26, uncovered: 655
# Current coverage: 0.7512, path length: 27, uncovered: 622
# Current coverage: 0.7716, path length: 28, uncovered: 571
# Current coverage: 0.8088, path length: 29, uncovered: 478
# Current coverage: 0.8160, path length: 30, uncovered: 460
# Current coverage: 0.8180, path length: 31, uncovered: 455
# Current coverage: 0.8200, path length: 32, uncovered: 450
# Current coverage: 0.8224, path length: 33, uncovered: 444
# Current coverage: 0.8264, path length: 34, uncovered: 434
# Current coverage: 0.8556, path length: 35, uncovered: 361
# Current coverage: 0.8684, path length: 36, uncovered: 329
# Current coverage: 0.8728, path length: 37, uncovered: 318
# Current coverage: 0.8932, path length: 38, uncovered: 267
# Current coverage: 0.9004, path length: 39, uncovered: 249
# Current coverage: 0.9168, path length: 40, uncovered: 208
# Current coverage: 0.9172, path length: 41, uncovered: 207
# Current coverage: 0.9252, path length: 42, uncovered: 187
# Current coverage: 0.9308, path length: 43, uncovered: 173
# Current coverage: 0.9324, path length: 44, uncovered: 169
# Current coverage: 0.9364, path length: 45, uncovered: 159
# Current coverage: 0.9388, path length: 46, uncovered: 153
# Current coverage: 0.9532, path length: 47, uncovered: 117
# Current coverage: 0.9544, path length: 48, uncovered: 114
# Current coverage: 0.9572, path length: 49, uncovered: 107
# Current coverage: 0.9664, path length: 50, uncovered: 84
# Current coverage: 0.9696, path length: 51, uncovered: 76
# Current coverage: 0.9776, path length: 52, uncovered: 56
# Current coverage: 0.9792, path length: 53, uncovered: 52
# Iteration 0: Best ObjFun = 1163.25, Current ObjFun = 1163.25
# Iteration 1: Best ObjFun = 1160.58, Current ObjFun = 1160.58
# Iteration 2: Best ObjFun = 1156.82, Current ObjFun = 1156.82
# Iteration 3: Best ObjFun = 1156.61, Current ObjFun = 1156.61
# Iteration 4: Best ObjFun = 1155.48, Current ObjFun = 1155.48
# Iteration 5: Best ObjFun = 1155.43, Current ObjFun = 1155.43
# Iteration 6: Best ObjFun = 1148.52, Current ObjFun = 1148.52
# Iteration 7: Best ObjFun = 1148.49, Current ObjFun = 1148.49
# Iteration 8: Best ObjFun = 1148.42, Current ObjFun = 1148.42
# Iteration 9: Best ObjFun = 1147.77, Current ObjFun = 1147.77

# %%
display_grid_and_path(instance, evaluator, solution.path)
# Out:
# Coverage: 2460/2500 nodes (98.4%)

# %%
solution.cache["hits_obstacle"]
# Out:
# False
