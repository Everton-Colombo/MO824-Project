# %%
from agricultural_csp.instance import *
from agricultural_csp.evaluator import *
from agricultural_csp.solver.agcsp_ts import *

import numpy as np
import matplotlib.pyplot as plt
from typing import List, Tuple

# %%
def display_grid_and_path(inst, evaluator, path):
    """
    Display a grid with nodes and path coverage visualization.
    
    Args:
        inst: AgcspInstance object containing grid_nodes and obstacle_nodes
        evaluator: AgcspEvaluator object to calculate coverage
        path: List of (row, col) tuples representing the path
    """
    covered_nodes = evaluator.get_covered_nodes_list(path)
    
    total_nodes = len(inst.field_nodes)
    covered_count = len(covered_nodes)
    coverage_percentage = (covered_count / total_nodes) * 100 if total_nodes > 0 else 0
    
    # Check for obstacle coverage
    covered_obstacles = []
    obstacle_warning = ""
    if hasattr(inst, 'obstacle_nodes') and len(inst.obstacle_nodes) > 0:
        covered_set = set(map(tuple, covered_nodes))
        covered_obstacles = [obs for obs in inst.obstacle_nodes if tuple(obs) in covered_set]
        if covered_obstacles:
            obstacle_warning = f" - {len(covered_obstacles)} obstacles covered!"
    
    plt.figure(figsize=(12, 10))
    
    # Plot valid nodes
    plt.scatter(inst.grid_nodes[:, 0], inst.grid_nodes[:, 1], c='#AAAAAA', s=3, 
               label='Uncovered Nodes', alpha=0.7)
    
    if len(covered_nodes) > 0:
        plt.scatter(covered_nodes[:, 0], covered_nodes[:, 1], c='#00AA44', s=4, 
                   label='Covered Nodes', alpha=0.8)
    
    # Plot obstacles
    if hasattr(inst, 'obstacle_nodes') and len(inst.obstacle_nodes) > 0:
        plt.scatter(inst.obstacle_nodes[:, 0], inst.obstacle_nodes[:, 1], c='#CC0000', s=4, 
                   marker='s', label='Obstacles', linewidths=0.5)
        
        # Highlight covered obstacles
        if covered_obstacles:
            covered_obstacles_arr = np.array(covered_obstacles)
            plt.scatter(covered_obstacles_arr[:, 0], covered_obstacles_arr[:, 1], 
                       c='#FF6600', s=10, marker='D', 
                       linewidths=2, label='Covered Obstacles')
    
    # Plot path
    if len(path) > 0:
        path_arr = np.array(path)
        plt.plot(path_arr[:, 0], path_arr[:, 1], color='#9900CC', linewidth=3, 
                label='Sprayer Path', marker='o', markersize=6, markerfacecolor='white', 
                markeredgecolor='#9900CC', markeredgewidth=2)
    
    # Plot start point (green star)
    if len(path) > 0:
        plt.scatter(path_arr[0, 0], path_arr[0, 1], c='#00DD00', s=200, 
                   marker='*', label='Start', edgecolors='black', linewidths=2, zorder=5)
    
    # Plot end point (red square)
    if len(path) > 1:
        plt.scatter(path_arr[-1, 0], path_arr[-1, 1], c='#DD0000', s=100, 
                   marker='s', label='End', edgecolors='black', linewidths=2, zorder=5)
    
    plt.axis('equal')
    plt.legend(loc='upper right', framealpha=0.9)
    
    title = f'Coverage: {covered_count}/{total_nodes} nodes ({coverage_percentage:.1f}%){obstacle_warning}'
    plt.title(title, fontsize=12, fontweight='bold')
    
    print(f"Coverage: {covered_count}/{total_nodes} nodes ({coverage_percentage:.1f}%)")
    if hasattr(inst, 'obstacle_nodes') and len(inst.obstacle_nodes) > 0:
        print(f"Obstacles: {len(covered_obstacles)}/{len(inst.obstacle_nodes)} covered")
        if covered_obstacles:
            print("WARNING: Sprayer is covering obstacles!")
    
    plt.show()

# %%
# Create a 50 x 50 square grid with five small square obstacles scattered on the grid
obstacle_half_size = 2  # Half-size of each small square obstacle

r_grid, c_grid = np.mgrid[0:50, 0:50]
grid_nodes = np.argwhere((r_grid >= 0) & (r_grid < 50) & (c_grid >= 0) & (c_grid < 50))

# Create five small square obstacles at different positions on the grid
obstacle_positions = [
    (10, 10),  # Top-left area
    (10, 40),  # Top-right area
    (25, 25),  # Center
    (40, 10),  # Bottom-left area
    (40, 40)   # Bottom-right area
]

obstacle_list = []
for obs_r, obs_c in obstacle_positions:
    obstacle = np.argwhere(
        (np.abs(r_grid - obs_r) <= obstacle_half_size) & 
        (np.abs(c_grid - obs_c) <= obstacle_half_size)
    )
    obstacle_list.append(obstacle)

obstacle_nodes = np.vstack(obstacle_list)

instance = AgcspInstance(grid_nodes, obstacle_nodes, 5, 90)
evaluator = AgcspEvaluator(instance)

# %%
display_grid_and_path(inst=instance, evaluator=evaluator, path=[])
# Out:
# Coverage: 0/2375 nodes (0.0%)
# Obstacles: 0/125 covered

# %%
ts = AgcspTS(instance, tenure=100, termination_criteria=TerminationCriteria(max_iterations=100), debug_options=DebugOptions(verbose=True))

# %%
gen_path = ts._constructive_heuristic(ConstructiveHeuristicType.FSM_COVERAGE_PLANNER)
# Out:
# After axis scanning 'C', current coverage: 91.58%
# After axis scanning 'R', current coverage: 99.83%
# Path simplification reduced points from 1116 to 80.

# %%
evaluator.objfun(gen_path)
# Out:
# 1249.2423481477442

# %%
display_grid_and_path(instance, evaluator, gen_path.path)
# Out:
# Coverage: 2371/2375 nodes (99.8%)
# Obstacles: 0/125 covered

# %%
solution = ts.solve()
# Out:
# Current coverage: 0.0021, path length: 1, uncovered: 2495
# Current coverage: 0.0876, path length: 2, uncovered: 2292
# Current coverage: 0.1019, path length: 3, uncovered: 2258
# Current coverage: 0.1339, path length: 4, uncovered: 2182
# Current coverage: 0.1802, path length: 5, uncovered: 2072
# Current coverage: 0.2131, path length: 6, uncovered: 1994
# Current coverage: 0.2265, path length: 7, uncovered: 1962
# Current coverage: 0.2817, path length: 8, uncovered: 1831
# Current coverage: 0.2973, path length: 9, uncovered: 1794
# Current coverage: 0.3246, path length: 10, uncovered: 1729
# Current coverage: 0.3356, path length: 11, uncovered: 1703
# Current coverage: 0.3655, path length: 12, uncovered: 1632
# Current coverage: 0.4076, path length: 13, uncovered: 1532
# Current coverage: 0.4232, path length: 14, uncovered: 1495
# Current coverage: 0.5053, path length: 15, uncovered: 1300
# Current coverage: 0.5112, path length: 16, uncovered: 1286
# Current coverage: 0.5229, path length: 17, uncovered: 1258
# Current coverage: 0.5297, path length: 18, uncovered: 1242
# Current coverage: 0.5301, path length: 19, uncovered: 1241
# Current coverage: 0.5436, path length: 20, uncovered: 1209
# Current coverage: 0.5507, path length: 21, uncovered: 1192
# Current coverage: 0.5756, path length: 22, uncovered: 1133
# Current coverage: 0.6328, path length: 23, uncovered: 997
# Current coverage: 0.6522, path length: 24, uncovered: 951
# Current coverage: 0.6716, path length: 25, uncovered: 905
# Current coverage: 0.7040, path length: 26, uncovered: 828
# Current coverage: 0.7099, path length: 27, uncovered: 814
# Current coverage: 0.7263, path length: 28, uncovered: 775
# Current coverage: 0.7309, path length: 29, uncovered: 764
# Current coverage: 0.7368, path length: 30, uncovered: 750
# Current coverage: 0.7427, path length: 31, uncovered: 736
# Current coverage: 0.7512, path length: 32, uncovered: 716
# Current coverage: 0.7613, path length: 33, uncovered: 692
# Current coverage: 0.7709, path length: 34, uncovered: 669
# Current coverage: 0.7764, path length: 35, uncovered: 656
# Current coverage: 0.7869, path length: 36, uncovered: 631
# Current coverage: 0.8046, path length: 37, uncovered: 589
# Current coverage: 0.8131, path length: 38, uncovered: 569
# Current coverage: 0.8291, path length: 39, uncovered: 531
# Current coverage: 0.8463, path length: 40, uncovered: 490
# Current coverage: 0.8526, path length: 41, uncovered: 475
# No valid uncovered nodes found. Trying covered nodes near uncovered areas...
# Added covered node near uncovered area: (5, 42)
# Current coverage: 0.8531, path length: 42, uncovered: 474
# No valid uncovered nodes found. Trying covered nodes near uncovered areas...
# Added covered node near uncovered area: (6, 45)
# Current coverage: 0.8539, path length: 43, uncovered: 472
# Current coverage: 0.8619, path length: 44, uncovered: 453
# Current coverage: 0.8632, path length: 45, uncovered: 450
# Current coverage: 0.8728, path length: 46, uncovered: 427
# Current coverage: 0.8893, path length: 47, uncovered: 388
# No valid uncovered nodes found. Trying covered nodes near uncovered areas...
# Added covered node near uncovered area: (12, 4)
# Current coverage: 0.8905, path length: 48, uncovered: 385
# Current coverage: 0.8935, path length: 49, uncovered: 378
# Current coverage: 0.8977, path length: 50, uncovered: 368
# Current coverage: 0.9166, path length: 51, uncovered: 323
# Current coverage: 0.9183, path length: 52, uncovered: 319
# Current coverage: 0.9251, path length: 53, uncovered: 303
# Current coverage: 0.9297, path length: 54, uncovered: 292
# No valid uncovered nodes found. Trying covered nodes near uncovered areas...
# Could not find any valid node to add from 292 candidates.
# Iteration 0: Best ObjFun = 2679.83, Current ObjFun = 2679.83
# Iteration 1: Best ObjFun = 2591.85, Current ObjFun = 2591.85
# Iteration 2: Best ObjFun = 2524.39, Current ObjFun = 2524.39
# Iteration 3: Best ObjFun = 2502.49, Current ObjFun = 2502.49
# Iteration 4: Best ObjFun = 2469.23, Current ObjFun = 2469.23
# Iteration 5: Best ObjFun = 2342.44, Current ObjFun = 2342.44
# Iteration 6: Best ObjFun = 2335.82, Current ObjFun = 2335.82
# Iteration 7: Best ObjFun = 2334.97, Current ObjFun = 2334.97
# Iteration 8: Best ObjFun = 2292.98, Current ObjFun = 2292.98
# Iteration 9: Best ObjFun = 2280.42, Current ObjFun = 2280.42
# Iteration 10: Best ObjFun = 2280.41, Current ObjFun = 2280.41
# Iteration 11: Best ObjFun = 2247.02, Current ObjFun = 2247.02
# Iteration 12: Best ObjFun = 2199.69, Current ObjFun = 2199.69
# Iteration 13: Best ObjFun = 2178.01, Current ObjFun = 2178.01
# Iteration 14: Best ObjFun = 2175.41, Current ObjFun = 2175.41
# Iteration 15: Best ObjFun = 2124.04, Current ObjFun = 2124.04
# Iteration 16: Best ObjFun = 2124.03, Current ObjFun = 2124.03
# Iteration 17: Best ObjFun = 2103.08, Current ObjFun = 2103.08
# Iteration 18: Best ObjFun = 2072.80, Current ObjFun = 2072.80
# Iteration 19: Best ObjFun = 2020.14, Current ObjFun = 2020.14
# Iteration 20: Best ObjFun = 1980.72, Current ObjFun = 1980.72
# Iteration 21: Best ObjFun = 1974.09, Current ObjFun = 1974.09
# Iteration 22: Best ObjFun = 1974.05, Current ObjFun = 1974.05
# Iteration 23: Best ObjFun = 1973.97, Current ObjFun = 1973.97
# Iteration 24: Best ObjFun = 1937.35, Current ObjFun = 1937.35
# Iteration 25: Best ObjFun = 1937.29, Current ObjFun = 1937.29
# Iteration 26: Best ObjFun = 1935.62, Current ObjFun = 1935.62
# Iteration 27: Best ObjFun = 1925.47, Current ObjFun = 1925.47
# Iteration 28: Best ObjFun = 1921.54, Current ObjFun = 1921.54
# Iteration 29: Best ObjFun = 1912.01, Current ObjFun = 1912.01
# Iteration 30: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 31: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 32: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 33: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 34: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 35: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 36: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 37: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 38: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 39: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 40: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 41: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 42: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 43: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 44: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 45: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 46: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 47: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 48: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 49: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 50: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 51: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 52: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 53: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 54: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 55: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 56: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 57: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 58: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 59: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 60: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 61: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 62: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 63: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 64: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 65: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 66: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 67: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 68: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 69: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 70: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 71: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 72: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 73: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 74: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 75: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 76: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 77: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 78: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 79: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 80: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 81: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 82: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 83: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 84: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 85: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 86: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 87: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 88: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 89: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 90: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 91: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 92: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 93: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 94: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 95: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 96: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 97: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 98: Best ObjFun = 1901.66, Current ObjFun = 1901.66
# Iteration 99: Best ObjFun = 1901.66, Current ObjFun = 1901.66

# %%
display_grid_and_path(instance, evaluator, solution.path)
# Out:
# Coverage: 2292/2375 nodes (96.5%)
# Obstacles: 0/125 covered

# %%
solution.cache["hits_obstacle"]
# Out:
# False
